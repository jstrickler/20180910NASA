# %% [markdown]
# # Saving Matplotlib figures

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib notebook
# %matplotlib inline
import pickle
import math

# %%
x_values = range(1,51)
y_values = [math.cos(i) for i in x_values]

# %%
plt.plot(x_values, y_values)

# %%
fig = plt.gcf()
with open('saved_plot.fig', 'wb') as fig_out:
    pickle.dump(fig, fig_out)

# %%
with open('saved_plot.fig', 'rb') as fig_in:
    saved_fig = pickle.load(fig_in)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-f8bf5598c563> in <module>()
#       1 with open('saved_plot.fig', 'rb') as fig_in:
# ----> 2     saved_fig = pickle.load(fig_in)
#
# ~/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/site-packages/matplotlib/figure.py in __setstate__(self, state)
#    1444             allnums = plt.get_fignums()
#    1445             num = max(allnums) + 1 if allnums else 1
# -> 1446             mgr = plt._backend_mod.new_figure_manager_given_figure(num, self)
#    1447
#    1448             # XXX The following is a copy and paste from pyplot. Consider
#
# AttributeError: module 'ipykernel.pylab.backend_inline' has no attribute 'new_figure_manager_given_figure'
